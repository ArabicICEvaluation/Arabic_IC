# %%
# %pip install arabic-reshaper python-bidi
# Out:
# ...
#   Using cached arabic_reshaper-3.0.0-py3-none-any.whl.metadata (12 kB)
# ...
# Using cached arabic_reshaper-3.0.0-py3-none-any.whl (20 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import glob
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
import requests
from PIL import Image
from io import BytesIO
import arabic_reshaper
from bidi.algorithm import get_display
import textwrap
from math import ceil
import time

# %%
plt.set_cmap('gray')

# %% [markdown]
# # Load Arabic Flickr8k Dataset

# %%
data = pd.read_csv('artifacts/caption_data_for_Flickr8k.csv')
data.head()

# %%
print("Missing values in data:")
if 'data' in locals() and isinstance(data, pd.DataFrame):
    display(data.isnull().sum())
else:
    print("data not found or is not a DataFrame.")

# %%
print("Original shape of 'data':", data.shape)
data.dropna(inplace=True)
print("Shape of 'data' after dropping NaNs:", data.shape)

# %%
print("Missing values in data after removal:")
display(data.isnull().sum())

# %%
# Remove rows where any of the caption columns are empty strings
data = data[data['Ref1'] != '']
data = data[data['Ref2'] != '']
data = data[data['Ref3'] != '']

print("Shape of 'caption_data' after removing empty strings:", data.shape)

# %%
output_file_path = 'artifacts/caption_data_for_Flickr8k.csv'
caption_data.to_csv(output_file_path, index=False)
print(f"data DataFrame successfully saved to {output_file_path}")
